# %%
# Read a JSON File Into a Pandas DataFrame
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_json('./mooninfo_2023.json')

# %%
print(df.head())
# Out:
#                    time  phase    age  diameter  distance  \
# 0  01 Jan 2023 00:00 UT  69.94  8.572    1839.7    389583
# 1  01 Jan 2023 01:00 UT  70.33  8.613    1838.8    389773
# 2  01 Jan 2023 02:00 UT  70.71  8.655    1837.9    389962
# 3  01 Jan 2023 03:00 UT  71.10  8.697    1837.1    390149
# 4  01 Jan 2023 04:00 UT  71.48  8.738    1836.2    390336
#
#                             j2000  \
# 0  {'ra': 2.0904, 'dec': 11.9445}
# 1  {'ra': 2.1233, 'dec': 12.1681}
# 2  {'ra': 2.1562, 'dec': 12.3905}
# 3  {'ra': 2.1892, 'dec': 12.6119}
# 4  {'ra': 2.2222, 'dec': 12.8321}
#
#                                       subsolar                      subearth  \
# 0               {'lon': 73.501, 'lat': -1.348}  {'lon': 7.034, 'lat': 0.862}
# 1               {'lon': 72.995, 'lat': -1.349}    {'lon': 7.013, 'lat': 0.8}
# 2                {'lon': 72.489, 'lat': -1.35}  {'lon': 6.992, 'lat': 0.739}
# 3               {'lon': 71.982, 'lat': -1.351}   {'lon': 6.97, 'lat': 0.678}
# ...

# %%
sample = df[['time','distance', 'phase']]

# %%
sample.set_index('time')
# Out:
#                       distance  phase
# time
# 01 Jan 2023 00:00 UT    389583  69.94
# 01 Jan 2023 01:00 UT    389773  70.33
# 01 Jan 2023 02:00 UT    389962  70.71
# 01 Jan 2023 03:00 UT    390149  71.10
# 01 Jan 2023 04:00 UT    390336  71.48
# ...                        ...    ...
# 31 Dec 2023 19:00 UT    404458  79.63
# 31 Dec 2023 20:00 UT    404497  79.31
# 31 Dec 2023 21:00 UT    404534  79.00
# 31 Dec 2023 22:00 UT    404570  78.68
# 31 Dec 2023 23:00 UT    404603  78.36
#
# [8760 rows x 2 columns]

# %%
df['distance'].plot()
ax = df['phase'].plot(secondary_y=True)
plt.show()
