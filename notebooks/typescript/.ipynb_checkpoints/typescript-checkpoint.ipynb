// %%
console.log('hello world')
// Out:
// hello world

// %%
import * as tslab from 'tslab';

tslab.display.html("<h1>Hello TS Notebook!</h1>");
// Out:
// <h1>Hello TS Notebook!</h1>

// %%
import {readFileSync} from 'fs';
const image = readFileSync(`./images/uguisu.jpeg`);
tslab.display.jpeg(image);

// %% [markdown]
// ## Test
// - one
// - two
// - three
//   - sorta
//   - maybe
//   - I guess...
